# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
np.random.seed(42)
X = np.linspace(-3, 3, 100).reshape(-1, 1)
y = 2 * X**2 + 3*X + 5 + np.random.randn(100,1) * 2

# %%
X[:10], y[:10]  # Display first 10 samples
# Out:
# (array([[-3.        ],
#         [-2.93939394],
#         [-2.87878788],
#         [-2.81818182],
#         [-2.75757576],
#         [-2.6969697 ],
#         [-2.63636364],
#         [-2.57575758],
#         [-2.51515152],
#         [-2.45454545]]),
#  array([[14.99342831],
#         [13.18536304],
#         [14.23385274],
#         [15.47581178],
#         [11.4674141 ],
#         [10.98810809],
#         [14.15016117],
#         [12.07665091],
#         [ 9.16757097],
#         [10.7710705 ]]))

# %%
lin_reg = LinearRegression()
lin_reg.fit(X, y)
y_pred = lin_reg.predict(X)

# %%
poly = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly.fit_transform(X)
poly_reg = LinearRegression()
poly_reg.fit(X_poly, y)
y_poly_pred = poly_reg.predict(X_poly)

# %%
plt.scatter(X, y, color="gray", label="actul data")
plt.plot(X, y_pred, color="red", label="linear regression (1°)")
plt.plot(X, y_poly_pred, color="blue", label="polynomial regression (2°)")
plt.legend()
plt.show()
